# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def line_intersects_sphere(p1, p2, center, radius):
    """
    Check if the line segment from p1 to p2 intersects the sphere with the given center and radius.
    """
    d = p2 - p1
    f = p1 - center
    a = np.dot(d, d)
    b = 2 * np.dot(f, d)
    c = np.dot(f, f) - radius ** 2
    discriminant = b ** 2 - 4 * a * c

    print(f"Checking line segment {p1} to {p2} against sphere centered at {center} with radius {radius}")
    print(f"Discriminant: {discriminant}")

    if discriminant < 0:
        print("No intersection.")
        return False

    discriminant = np.sqrt(discriminant)
    t1 = (-b - discriminant) / (2 * a)
    t2 = (-b + discriminant) / (2 * a)

    print(f"t1: {t1}, t2: {t2}")

    if (0 <= t1 <= 1) or (0 <= t2 <= 1):
        print("Intersection detected.")
        return True

    print("No intersection within the line segment.")
    return False

def plot_line_and_sphere(p1, p2, center, radius):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Create a sphere
    u = np.linspace(0, 2 * np.pi, 100)
    v = np.linspace(0, np.pi, 100)
    x = center[0] + radius * np.outer(np.cos(u), np.sin(v))
    y = center[1] + radius * np.outer(np.sin(u), np.sin(v))
    z = center[2] + radius * np.outer(np.ones(np.size(u)), np.cos(v))

    # Plot the sphere
    ax.plot_surface(x, y, z, color='r', alpha=0.3)

    # Plot the line segment
    ax.plot([p1[0], p2[0]], [p1[1], p2[1]], [p1[2], p2[2]], 'b--')
    ax.scatter(center[0], center[1], center[2], color='r')
    ax.scatter([p1[0], p2[0]], [p1[1], p2[1]], [p1[2], p2[2]], color='b')

    # Set plot limits
    ax.set_xlim([min(p1[0], p2[0], center[0]) - radius - 1, max(p1[0], p2[0], center[0]) + radius + 1])
    ax.set_ylim([min(p1[1], p2[1], center[1]) - radius - 1, max(p1[1], p2[1], center[1]) + radius + 1])
    ax.set_zlim([min(p1[2], p2[2], center[2]) - radius - 1, max(p1[2], p2[2], center[2]) + radius + 1])

    plt.show()

# Example points and sphere for debugging
p1 = np.array([0, 0, 0])
p2 = np.array([-1, -1, -1])
center = np.array([1, 1, 1])
radius = 1

# Check intersection
line_intersects_sphere(p1, p2, center, radius)

# Plot the situation
plot_line_and_sphere(p1, p2, center, radius)
# Out:
# Checking line segment [0 0 0] to [-1 -1 -1] against sphere centered at [1 1 1] with radius 1
# Discriminant: 12
# t1: -1.5773502691896255, t2: -0.42264973081037427
# No intersection within the line segment.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# Read the CSV file
data = pd.read_csv('/home/michael/autoDroneRepos/lsy_drone_racing/target_vs_control.csv')

# Create a new figure for the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot target positions
ax.plot(data['Target X'], data['Target Y'], data['Target Z'], 'ro-', label='Target Position', markersize=5)

# Plot control outputs
ax.plot(data['Control X'], data['Control Y'], data['Control Z'], 'bo-', label='Control Output', markersize=5)

# Adding labels and legend
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('PID Control Output and Target Position')
ax.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def move_waypoint_if_within_buffer(waypoint, x_c, y_c, x_gate, y_gate, yaw, buffer):
    # Calculate the distance between the waypoint and the cylinder center
    distance = np.sqrt((waypoint[0] - x_c)**2 + (waypoint[1] - y_c)**2)
    
    # Check if the waypoint is within the buffer distance
    if distance < buffer:
        # Calculate the displacement needed to move it to the buffer distance
        displacement = buffer - distance
        
        # Calculate the angle perpendicular to the yaw
        perpendicular_yaw = yaw + np.pi / 2
        
        # Calculate the unit vector along the perpendicular direction
        unit_vector = np.array([np.cos(perpendicular_yaw), np.sin(perpendicular_yaw)])
        
        # Move the waypoint along the perpendicular direction
        new_waypoint = waypoint + displacement * unit_vector
        
        return new_waypoint
    else:
        return waypoint

# Example usage
waypoint = np.array([1.0, 1.0])
x_c, y_c = 1.2, 1.2  # Cylinder center coordinates
x_gate, y_gate = 0.0, 0.0  # Line center coordinates (not used directly here)
yaw = np.pi / 4  # 45 degrees in radians
buffer = 0.35  # Buffer distance

new_waypoint = move_waypoint_if_within_buffer(waypoint, x_c, y_c, x_gate, y_gate, yaw, buffer)

# Plotting
fig, ax = plt.subplots()

# Plot the cylinder
cylinder = plt.Circle((x_c, y_c), buffer, color='blue', alpha=0.5, label='Buffer Zone')
ax.add_artist(cylinder)

# Plot the original waypoint
ax.plot(waypoint[0], waypoint[1], 'ro', label='Original Waypoint')

# Plot the new waypoint
ax.plot(new_waypoint[0], new_waypoint[1], 'go', label='Adjusted Waypoint')

# Plot the cylinder center
ax.plot(x_c, y_c, 'bo', label='Cylinder Center')

# Set the plot limits
ax.set_xlim(0, 2)
ax.set_ylim(0, 2)

# Add labels and legend
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Waypoint Adjustment Around Cylinder')
ax.legend()

plt.show()

print("Original Waypoint:", waypoint)
print("New Waypoint:", new_waypoint)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       4 def move_waypoint_if_within_buffer(waypoint, x_c, y_c, x_gate, y_gate, yaw, buffer):
#       5     # Calculate the distance between the waypoint and the cylinder center
#       6     distance = np.sqrt((waypoint[0] - x_c)**2 + (waypoint[1] - y_c)**2)
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:109
#     105 from packaging.version import parse as parse_version
#     107 # cbook must import matplotlib only within function
#     108 # definitions, so it is safe to import from it here.
# --> 109 from . import _api, _version, cbook, docstring, rcsetup
#     110 from matplotlib.cbook import MatplotlibDeprecationWarning, sanitize_sequence
#     111 from matplotlib.cbook import mplDeprecation  # deprecated
#
# ...
